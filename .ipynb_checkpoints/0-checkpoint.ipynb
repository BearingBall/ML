# %%
import ZeroConstructions as zc
import numpy as np
# %load_ext autoreload
# %autoreload 2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# C:\Users\4689~1\AppData\Local\Temp/ipykernel_17236/1865183133.py in <module>
# ----> 1 import ZeroConstructions as zc
#       2 import numpy as np
#       3 get_ipython().run_line_magic('load_ext', 'autoreload')
#       4 get_ipython().run_line_magic('autoreload', '2')
#
# ModuleNotFoundError: No module named 'ZeroConstructions'

# %%
classifiers = zc.getBinaryClassifiers()
classifiers = zc.CalClassifiers(classifiers)
dataset = zc.getBinaryDataset()
zc.drawBinaryDataset(dataset)
X_train, X_test, y_train, y_test = zc.splitBinaryDataset(dataset)

# %%
zc.fitBinaryClassifiers(classifiers, X_train, y_train)

# %%
obj = zc.predictionTable(classifiers[0], X_test)
    
ind = np.argsort(obj)
obj = obj[ind]
y = y_test[ind]

prev = -1.0
for i in range(len(obj)):
    if (prev != obj[i]):
        print(obj[i], y[i])
        prev = obj[i]
# Out:
# 0.12729391744869933 0
# 0.16486138836048334 0
# 0.16520482715015522 0
# 0.16653274887738512 1
# 0.17502604636332894 1
# 0.20277229806193922 1
# 0.20410021978916912 0
# 0.21243447799830345 0
# 0.21259351727511291 1
# 0.21426487779201472 0
# 0.25034538769975934 0
# 0.2518323487037987 0
# 0.2559589811664607 1
# 0.2895842191284451 0
# 0.2897432584052546 0
# 0.29807751661438886 0
# 0.2994054383416188 1
# 0.2997488771312907 1
# 0.33731634804307464 0
# 0.33943329160809527 1
# 0.34207931008836245 1
# 0.3514921902819852 0
# 0.3520849288143986 1
# 0.3553005605465696 0
# 0.36363481875570386 0
# 0.36496274048293376 0
# 0.36721949312296226 1
# 0.3871654205227248 0
# 0.3896523997261826 1
# 0.39922431919661483 1
# 0.40287365018438964 0
# 0.41495162203759184 0
# 0.4267425803321502 1
# 0.43950147220583274 0
# 0.4515603708797227 1
# 0.4527227226640398 1
# 0.458226091871508 1
# 0.4647816213379298 1
# 0.46728767372069974 1
# 0.5014094433593728 0
# 0.51463069381758 1
# 0.5171367462003499 1
# 0.526708665670782 0
# 0.5291956448742399 1
# 0.530357996658557 0
# 0.5543550581106411 0
# 0.5555141155868691 1
# 0.5669667455006878 1
# 0.5761194456959309 1
# 0.57904471735389 1
# 0.5826940483416648 0
# 0.5922659678120971 1
# 0.5947529470155548 0
# 0.6065439053101132 1
# 0.6100056529786972 0
# 0.644434454798294 0
# 0.644602019495205 1
# 0.6841791793046303 1
# 0.6854576241477215 1
# 0.6876409269732144 0
# 0.6878764893291212 1
# 0.6942835272779442 0
# 0.7159732021079551 0
# 0.7338606870873695 1
# 0.7375579971118603 1
# 0.7546167622579801 1
# 0.7680736914351562 1
# 0.774716291739886 0
# 0.7768995945653789 0
# 0.7805969045898697 1
# 0.8177551992178955 1
# 0.8179907615738022 1
# 0.8201740643992952 0
# 0.8214525092423862 1
# 0.8610296690518118 1

# %%
#zc.drawRocTable(np.array([0.1,0.4,0.6,0.8]), np.array([0,0,1,1]))
#zc.drawRocTable(np.array([1, 1, 1, 0, 0]), np.array([1, 1, 1, 0, 0]))
zc.drawRocTable(obj, y)

# %%
#zc.drawPRTable(np.array([0.1,0.4,0.6,0.8]), np.array([0,0,1,1]))
#zc.drawPRTable(np.array([1, 1, 1, 0, 0]), np.array([1, 1, 1, 0, 0]))
zc.drawPRTable(obj, y)

# %%
X_train_random = np.random.random((600,2))
y_train_random = np.ndarray.astype(np.random.random(600) + 0.5, dtype = np.int) 
obj_random = np.ndarray.astype(np.random.random(600) + 0.5, dtype = np.int) 
zc.drawBinaryDataset((X_train_random, y_train_random))
# Out:
# <ipython-input-12-75339f443e9b>:2: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   y_train_random = np.ndarray.astype(np.random.random(600) + 0.5, dtype = np.int)
# <ipython-input-12-75339f443e9b>:3: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   obj_random = np.ndarray.astype(np.random.random(600) + 0.5, dtype = np.int)

# %%
zc.drawRocTable(obj_random, y_train_random)

# %%
zc.drawPRTable(obj_random, y_train_random)
